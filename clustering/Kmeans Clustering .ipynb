# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
data18 = pd.read_csv("data18_c_d.csv")
data18 = data18.drop("Unnamed: 0", axis = 1)
data18_no_stars = data18[data18.columns[~data18.columns.str.contains("star")]].drop(["contract_name", "id", "name", "organization_type", "parent_org", "spring"], axis = 1)
data18_stars = data18[data18.columns[data18.columns.str.contains("star")]].drop(["c_health_plan_quality_improvement_star", "d_drug_plan_quality_improvement_star"], axis = 1)
data18_cutpoints = pd.read_csv("2018_cleaned/2018_Report_Card_Master_Table_2018_03_28_C_cutpoints.csv", encoding = "cp1252")

# %%
def cluster(column): 
    series = pd.Series(column)
    km = KMeans(n_clusters = 5)
    #should take out -1 otherwise the -1s will be their own cluster
    km.fit(np.array(pd.DataFrame(series.drop(series[series == -1].index))))
    return km

#kmeans starts with different centroids for each iteration, can yield different final centroids 
#repeat kmeans 1000 times and take the mean of the centroids for each cluster
def cluster_means(series, n_iters = 1000): 
    x = np.sort(np.array([cluster(series).cluster_centers_.flatten() for i in range(n_iters)]).flatten())
    one = x[0:n_iters]
    two = x[n_iters:(n_iters * 2)]
    three = x[(n_iters * 2):(n_iters * 3)]
    four = x[(n_iters * 3):(n_iters * 4)]
    five = x[(n_iters * 4):]
    df = pd.DataFrame({"1": one, "2": two, "3": three, "4": four, "5": five})
    return df.apply(lambda x: x.mean(), axis = 0).to_dict()

#points are classified based on which centroid they are closest to
#so cutpoints are the mean between the two closest centroids
def return_cutpoints(series): 
    cuts = cluster_means(series)
    cut1 = (cuts["1"] + cuts["2"])/2
    cut2 = (cuts["2"] + cuts["3"])/2
    cut3 = (cuts["3"] + cuts["4"])/2
    cut4 = (cuts["4"] + cuts["5"])/2
    return pd.Series({"1": cut1, "2": cut2, "3": cut3, "4": cut4})

def convert_to_stars(series): 
    cuts = cluster_means(series)
    cut1 = (cuts["1"] + cuts["2"])/2
    cut2 = (cuts["2"] + cuts["3"])/2
    cut3 = (cuts["3"] + cuts["4"])/2
    cut4 = (cuts["4"] + cuts["5"])/2
    return series.apply(lambda x: -1.0 if x == -1 else 
                                      1.0 if x < cut1 else 
                                      2.0 if (x >= cut1 and x < cut2) else
                                       3.0 if (x >= cut2 and x < cut3) else 
                                       4.0 if (x >= cut3 and x < cut4) else 
                                       5.0)

# %%
predicted = data18_no_stars.apply(convert_to_stars, axis = 0)

# %%
cutpoints = data18_no_stars.apply(return_cutpoints, axis = 0)

# %%
cutpoints
# Out:
#    c_adult_bmi_assessment  c_annual_flu_vaccine  \
# 1               66.533279             52.666781
# 2               84.542333             65.556883
# 3               92.960750             72.191662
# 4               97.214172             78.334740
#
#    c_beneficiary_access_and_performance_problems  c_breast_cancer_screening  \
# 1                                      20.623105                  50.157603
# 2                                      49.999355                  66.893845
# 3                                      70.000000                  74.089987
# 4                                      90.000000                  80.951131
#
#    c_call_center_foreign_language_interpreter_and_tty_availability  \
# 1                                          45.285375
# 2                                          72.411565
# 3                                          86.760145
# 4                                          94.541785
#
#    c_colorectal_cancer_screening  c_complaints_about_health_plan  \
# 1                      50.619014                        0.134430
# 2                      63.940049                        0.322101
# 3                      72.448839                        0.598040
# 4                      80.104453                        1.014717
#
#    c_controlling_blood_pressure  c_coordination  c_customer_service  \
# 1                     46.776124       82.712111           87.930483
# 2                     61.273127       85.079473           89.398271
# 3                     72.292632       86.910942           90.701506
# 4                     81.260140       88.965265           92.420062
#
#    c_diabetes_blood_sugar_controlled  c_diabetes_eye_exam  \
# 1                          30.468964            55.306654
# 2                          55.092239            65.190660
# 3                          69.483156            72.386809
# 4                          80.609276            80.345711
#
#    c_diabetes_kidney_disease_monitoring  c_getting_appointments_and_quickly  \
# 1                             92.599567                           71.954943
# 2                             94.618234                           75.635105
# 3                             96.200816                           78.542712
# 4                             97.670535                           81.573134
#
#    c_getting_needed_care  c_improving_bladder_control  \
# 1              75.179967                    37.288773
# 2              79.904882                    41.861731
# 3              82.823073                    45.825982
# 4              85.374009                    50.651456
#
#    c_improving_or_maintaining_mental_health  \
# 1                                 75.446739
# 2                                 81.356568
# 3                                 84.436607
# 4                                 87.171698
#
#    c_improving_or_maintaining_physical_health  \
# 1                                   58.254630
# 2                                   63.854528
# 3                                   67.323596
# 4                                   71.185585
#
#    c_medication_reconciliation_post_discharge  \
# 1                                   22.180034
# 2                                   40.191054
# 3                                   55.636347
# 4                                   71.181956
#
#    c_members_choosing_to_leave_plan  c_monitoring_physical_activity  \
# 1                          7.040999                       43.729010
# 2                         12.844023                       48.520609
# 3                         19.547286                       53.017739
# 4                         27.235395                       58.371164
#
#    c_older_adults_functional_status_assessment  \
# 1                                    41.880682
# 2                                    69.271670
# 3                                    83.738959
# 4                                    93.340072
#
#    c_older_adults_medication_review  c_older_adults_pain_assessment  \
# 1                         44.124639                       35.609250
# 2                         76.935705                       62.676278
# 3                         87.834977                       80.274494
# 4                         94.392475                       91.863233
#
#    c_osteoporosis_management_in_women_who_had_a_fracture  \
# 1                                          23.546946
# 2                                          37.115352
# 3                                          51.923577
# 4                                          67.764773
#
#    c_plan_all_cause_readmissions  c_plan_makes_timely_decisions_about_appeals  \
# 1                       6.039088                                    69.810955
# 2                       8.925791                                    81.979429
# 3                      11.146325                                    90.368911
# 4                      15.663828                                    96.570571
#
#    c_rating_of_health_plan  c_rating_of_health_quality  \
# 1                82.259931                   82.901121
# 2                84.827038                   84.877198
# 3                87.079762                   86.552815
# 4                89.955975                   88.379671
#
#    c_reducing_risk_of_falling  c_reviewing_appeals_decisions  \
# 1                   50.551493                      58.923077
# 2                   56.781508                      76.211823
# 3                   63.899838                      85.528068
# 4                   72.952044                      93.694362
#
#    c_rheumatoid_arthritis_management  c_special_needs_plan_management  \
# 1                          67.981540                        32.878571
# 2                          75.589120                        53.578371
# 3                          80.882630                        70.049719
# 4                          86.889301                        85.854145
#
#    d_appeals_autoforward  d_appeals_upheld  \
# 1               5.207095         60.243693
# 2              18.026568         74.091233
# 3              39.754207         83.330868
# 4             121.862140         91.476764
#
#    d_beneficiary_access_and_performance_problems  \
# 1                                      20.588235
# 2                                      50.000000
# 3                                      70.000000
# 4                                      90.000000
#
#    d_call_center_foreign_language_interpreter_and_tty_availability  \
# 1                                          48.957378
# 2                                          71.559585
# 3                                          85.580787
# 4                                          94.129010
#
#    d_complaints_about_drug_plan  d_getting_needed_prescription_drugs  \
# 1                      0.123046                            87.398925
# 2                      0.298569                            89.252953
# 3                      0.555596                            90.663988
# 4                      0.985257                            92.335473
#
#    d_medication_adherence_cholesterol  \
# 1                           65.812118
# 2                           74.214573
# 3                           79.093186
# 4                           83.232840
#
#    d_medication_adherence_diabetes_medications  \
# 1                                    72.480632
# 2                                    77.351432
# 3                                    81.404709
# 4                                    85.698753
#
#    d_medication_adherence_hypertension  d_members_choosing_to_leave_plan  \
# 1                            74.153123                          6.046430
# 2                            78.981159                         10.843918
# 3                            82.836261                         16.695306
# 4                            86.198501                         24.147840
#
#    d_mpf_price_accuracy  d_mtm_program_completion_rate_cmr  \
# 1             92.856686                          32.073301
# 2             97.356617                          48.153042
# 3             98.499932                          59.946334
# 4             99.500000                          74.302249
#
#    d_rating_of_drug_plan
# 1              80.084319
# 2              82.723058
# 3              85.047549
# 4              87.968879

# %%
accuracies = {}
for i in range(predicted.shape[1]): 
    accuracies[predicted.columns[i]] = accuracy_score(predicted.iloc[:,i], data18_stars.iloc[:,i])

# %%
accuracies
# Out:
# {'c_adult_bmi_assessment': 0.9683042789223455,
#  'c_annual_flu_vaccine': 0.7741679873217115,
#  'c_beneficiary_access_and_performance_problems': 1.0,
#  'c_breast_cancer_screening': 0.7852614896988906,
#  'c_call_center_foreign_language_interpreter_and_tty_availability': 0.9128367670364501,
#  'c_colorectal_cancer_screening': 0.9508716323296355,
#  'c_complaints_about_health_plan': 0.43106180665610144,
#  'c_controlling_blood_pressure': 0.7638668779714739,
#  'c_coordination': 0.8462757527733756,
#  'c_customer_service': 0.8605388272583201,
#  'c_diabetes_blood_sugar_controlled': 0.8985736925515055,
#  'c_diabetes_eye_exam': 0.8446909667194928,
#  'c_diabetes_kidney_disease_monitoring': 0.8074484944532488,
#  'c_getting_appointments_and_quickly': 0.9128367670364501,
#  'c_getting_needed_care': 0.7559429477020603,
#  'c_improving_bladder_control': 0.9350237717908082,
#  'c_improving_or_maintaining_mental_health': 0.9334389857369255,
#  'c_improving_or_maintaining_physical_health': 0.7329635499207607,
#  'c_medication_reconciliation_post_discharge': 0.8858954041204438,
#  'c_members_choosing_to_leave_plan': 0.4706814580031696,
#  'c_monitoring_physical_activity': 0.8518225039619651,
#  'c_older_adults_functional_status_assessment': 0.9239302694136292,
#  'c_older_adults_medication_review': 0.9667194928684627,
#  'c_older_adults_pain_assessment': 0.9635499207606973,
#  'c_osteoporosis_management_in_women_who_had_a_fracture': 0.9762282091917591,
#  'c_plan_all_cause_readmissions': 0.6973058637083994,
#  'c_plan_makes_timely_decisions_about_appeals': 0.9286846275752774,
#  'c_rating_of_health_plan': 0.713946117274168,
#  'c_rating_of_health_quality': 0.8304278922345484,
#  'c_reducing_risk_of_falling': 0.8969889064976229,
#  'c_reviewing_appeals_decisions': 0.9762282091917591,
#  'c_rheumatoid_arthritis_management': 0.7812995245641838,
#  'c_special_needs_plan_management': 0.9524564183835182,
#  'd_appeals_autoforward': 0.3359746434231379,
#  'd_appeals_upheld': 0.8605388272583201,
#  'd_beneficiary_access_and_performance_problems': 1.0,
#  'd_call_center_foreign_language_interpreter_and_tty_availability': 0.9429477020602218,
#  'd_complaints_about_drug_plan': 0.3629160063391442,
#  'd_getting_needed_prescription_drugs': 0.7210776545166403,
#  'd_medication_adherence_cholesterol': 0.9049128367670365,
#  'd_medication_adherence_diabetes_medications': 0.9112519809825673,
#  'd_medication_adherence_hypertension': 0.7155309033280507,
#  'd_members_choosing_to_leave_plan': 0.4009508716323296,
#  'd_mpf_price_accuracy': 0.30269413629160064,
#  'd_mtm_program_completion_rate_cmr': 0.866877971473851,
#  'd_rating_of_drug_plan': 0.7187004754358162}

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
data15 = pd.read_csv("2015/2015_data.csv")
data16 = pd.read_csv("2016/2016_data.csv")
data17= pd.read_csv("2017/2017_data.csv")
data18 = pd.read_csv("2018/2018_data.csv")
data19 = pd.read_csv("2019/2019_data_c.csv")

# %%
data19.head()
# Out:
#   Medicare Part C Display Measures                        Unnamed: 1  \
# 0                  Contract Number       Organization Marketing Name
# 1                            H0062                           Allwell
# 2                            H0490         Molina Healthcare of Ohio
# 3                            H0502          Contra Costa Health Plan
# 4                            H1189  CHRISTUS Health Plan Generations
#
#                                       Unnamed: 2  \
# 0                                  Contract Name
# 1  SUPERIOR HEALTHPLAN COMMUNITY SOLUTIONS, INC.
# 2                MOLINA HEALTHCARE OF OHIO, INC.
# 3                   THE CONTRA COSTA HEALTH PLAN
# 4                           CHRISTUS HEALTH PLAN
#
#                      Unnamed: 3                     Unnamed: 4  \
# 0           Parent Organization  Breast Cancer Screening - C01
# 1           Centene Corporation      Not enough data available
# ...

# %%
data15.columns = np.append(data15.iloc[0, 0:5], data15.iloc[1, 5:])

# %%
data15.iloc[1, :].values
# Out:
# array([nan, nan, nan, nan, nan, 'C01: Colorectal Cancer Screening',
#        'C02: Cardiovascular Care – Cholesterol Screening',
#        'C03: Diabetes Care – Cholesterol Screening',
#        'C04: Annual Flu Vaccine',
#        'C05: Improving or Maintaining Physical Health',
#        'C06: Improving or Maintaining Mental Health',
#        'C07: Monitoring Physical Activity', 'C08: Adult BMI Assessment',
#        'C09: Special Needs Plan (SNP) Care Management',
#        'C10: Care for Older Adults – Medication Review',
#        'C11: Care for Older Adults – Functional Status Assessment',
#        'C12: Care for Older Adults – Pain Assessment',
#        'C13: Osteoporosis Management in Women who had a Fracture',
#        'C14: Diabetes Care – Eye Exam',
#        'C15: Diabetes Care – Kidney Disease Monitoring',
#        'C16: Diabetes Care – Blood Sugar Controlled',
#        'C17: Diabetes Care – Cholesterol Controlled',
#        'C18: Controlling Blood Pressure',
# ...

# %%
data16.iloc[1, :].values
# Out:
# array([nan, nan, nan, nan, nan, 'C01: Breast Cancer Screening',
#        'C02: Colorectal Cancer Screening', 'C03: Annual Flu Vaccine',
#        'C04: Improving or Maintaining Physical Health',
#        'C05: Improving or Maintaining Mental Health',
#        'C06: Monitoring Physical Activity', 'C07: Adult BMI Assessment',
#        'C08: Special Needs Plan (SNP) Care Management',
#        'C09: Care for Older Adults – Medication Review',
#        'C10: Care for Older Adults – Functional Status Assessment',
#        'C11: Care for Older Adults – Pain Assessment',
#        'C12: Osteoporosis Management in Women who had a Fracture',
#        'C13: Diabetes Care – Eye Exam',
#        'C14: Diabetes Care – Kidney Disease Monitoring',
#        'C15: Diabetes Care – Blood Sugar Controlled',
#        'C16: Controlling Blood Pressure',
#        'C17: Rheumatoid Arthritis Management',
#        'C18: Reducing the Risk of Falling',
# ...

# %%
data15_2 = pd.read_csv("2015/2015_data_2.csv")
data16_2 = pd.read_csv("2016/2016_data_2.csv")
data17_2 = pd.read_csv("2017/2017_data_2.csv")
data18_2 = pd.read_csv("2018/2018_data_2.csv")
data19_2 = pd.read_csv("2019/2019_data_2.csv")

# %%
data15.columns = ["id", "organization", "contract", "marketing", "parent", 
                  "colorectal_cancer", "cardiovascular_cholesterol", "diabetes_cholesterol",
                  "flu", "physical_health", "mental_health", "physical_activity", 
                  "bmi", "special_needs", "older_medication", "older_functional", "older_pain", "osteoporosis",
                  "eye", "kidney", "blood_sugar", "cholesterol_controlled", "blood_pressure", "arthritis",
                  "bladder_control", "falling", "readmission", "needed_care",
                  "appointments_quickly", "customer_service", "health_care_quality", 
                  "health_plan_rating", "care_coordination", "health_plan_complaints", 
                  "leaving_plan", "health_plan_quality_improvement", "health_plan_appeals_time", 
                  "health_plan_appeals_review", "drug_plan_appeals_auto_forward", 
                  "drug_plan_appeals_upheld", "drug_plan_complaints", "leaving_drug_plan",
                  "drug_plan_quality_improvement", "drug_plan_rating", "needed_prescription_drugs", 
                  "price_accuracy", "high_risk_medication", "drug_diabetes_treatment", 
                  "medication_adherence_diabetes", "medication_adherence_hypertension", 
                  "medication_adherence_cholesterol"]
data16.columns = ["id", "organization", "contract", "marketing", "parent", 
                  "breast_cancer", "colorectal_cancer", "flu", "physical_health",
                  "mental_health", "physical_activity", "bmi", "special_needs", 
                  "older_medication", "older_functional", "older_pain", "osteoporosis",
                  "eye", "kidney", "blood_sugar", "blood_pressure", "arthritis", 
                  "falling", "readmission", "needed_care",
                  "appointments_quickly", "customer_service", "health_care_quality", 
                  "health_plan_rating", "care_coordination", "health_plan_complaints", 
                  "leaving_plan", "access_performance_problems", 
                  "health_plan_quality_improvement", "health_plan_appeals_time", 
                  "health_plan_appeals_review", "health_plan_foreign_language", 
                  "drug_plan_foreign_language", "drug_plan_appeals_auto_forward", 
                  "drug_plan_appeals_upheld", "drug_plan_complaints", "leaving_drug_plan",
                  "drug_plan_access_performance_problems", "drug_plan_quality_improvement", 
                  "drug_plan_rating", "needed_prescription_drugs", "price_accuracy", "high_risk_medication",
                  "medication_adherence_diabetes", "medication_adherence_hypertension", 
                  "medication_adherence_cholesterol", "completion_rate_cmr"]
data17.columns = ["id", "organization", "contract", "marketing", "parent", 
                  "breast_cancer", "colorectal_cancer", "flu", "physical_health",
                  "mental_health", "physical_activity", "bmi", "special_needs", 
                  "older_medication", "older_functional", "older_pain", "osteoporosis",
                  "eye", "kidney", "blood_sugar", "blood_pressure", "arthritis", 
                  "falling", "readmission", "needed_care",
                  "appointments_quickly", "customer_service", "health_care_quality", 
                  "health_plan_rating", "care_coordination", "health_plan_complaints", 
                  "leaving_plan", "access_performance_problems", 
                  "health_plan_quality_improvement", "health_plan_appeals_time", 
                  "health_plan_appeals_review", "health_plan_foreign_language", 
                  "drug_plan_foreign_language", "drug_plan_appeals_auto_forward", 
                  "drug_plan_appeals_upheld", "drug_plan_complaints", "leaving_drug_plan",
                  "drug_plan_access_performance_problems", "drug_plan_quality_improvement", 
                  "drug_plan_rating", "needed_prescription_drugs", "price_accuracy", "high_risk_medication",
                  "medication_adherence_diabetes", "medication_adherence_hypertension", 
                  "medication_adherence_cholesterol", "completion_rate_cmr"]
data18.columns = ["id", "organization", "contract", "marketing", "parent", 
                  "breast_cancer", "colorectal_cancer", "flu", "physical_health",
                  "mental_health", "physical_activity", "bmi", "special_needs", 
                  "older_medication", "older_functional", "older_pain", "osteoporosis",
                  "eye", "kidney", "blood_sugar", "blood_pressure", "arthritis", 
                  "falling", "bladder", "post_discharge", "readmission", "needed_care",
                  "appointments_quickly", "customer_service", "health_care_quality", 
                  "health_plan_rating", "care_coordination", "health_plan_complaints", 
                  "leaving_plan", "access_performance_problems", 
                  "health_plan_quality_improvement", "health_plan_appeals_time", 
                  "health_plan_appeals_review", "health_plan_foreign_language", 
                  "drug_plan_foreign_language", "drug_plan_appeals_auto_forward", 
                  "drug_plan_appeals_upheld", "drug_plan_complaints", "leaving_drug_plan",
                  "drug_plan_access_performance_problems", "drug_plan_quality_improvement", 
                  "drug_plan_rating", "needed_prescription_drugs", "price_accuracy", 
                  "medication_adherence_diabetes", "medication_adherence_hypertension", 
                  "medication_adherence_cholesterol", "completion_rate_cmr"]
data19.columns = ["id", "organization", "contract", "parent", "breast_cancer", 
                  "colorectal_cancer", "bmi", "older_medication", "older_functional", "older_pain", "osteoporosis",
                  "eye", "kidney", "blood_sugar", "blood_pressure", "arthritis",
                  "post_discharge", "readmission", "statin_therapy"]

# %%
data15_2.columns = np.append(data15_2.iloc[0, 0:4].values, data15_2.iloc[1, 4:])
data16_2.columns = np.append(data16_2.iloc[0, 0:4].values, data16_2.iloc[1, 4:])
data17_2.columns = np.append(data17_2.iloc[0, 0:4].values, data17_2.iloc[1, 4:])
data18_2.columns = np.append(data18_2.iloc[0, 0:4].values, data18_2.iloc[1, 4:])
data19_2.columns = np.append(data19_2.iloc[0, 0:4].values, data19_2.iloc[1, 4:])

# %%
data15_2
# Out:
#     Contract Number  \
# 0             E0654
# 1             E2332
# 2             E2630
# 3             E3014
# 4             E4744
# 5             E6322
# 6             E7316
# 7             E7848
# 8             H0022
# 9             H0028
# 10            H0084
# 11            H0104
# 12            H0107
# 13            H0108
# 14            H0117
# 15            H0137
# 16            H0141
# 17            H0147
# 18            H0148
# 19            H0150
# 20            H0151
# 21            H0154
# 22            H0192
# 23            H0248
# 24            H0251
# 25            H0281
# 26            H0294
# 27            H0302
# 28            H0303
# 29            H0316
# 30            H0317
# 31            H0318
# 32            H0319
# 33            H0320
# 34            H0321
# 35            H0332
# 36            H0336
# 37            H0351
# 38            H0354
# 39            H0408
# 40            H0423
# 41            H0435
# 42            H0439
# 43            H0480
# ...

# %%
len(data15_2.columns)
# Out:
# 45

# %%
data16_2.columns
# Out:
# Index(['Contract Number',
#        'Follow-up Visit after Hospital Stay for Mental Illness (within 30 days of discharge) - DMC01',
#        'Call Answer Timeliness - DMC02',
#        'Antidepressant Medication Management (6 months) - DMC03',
#        'Continuous Beta Blocker Treatment - DMC04',
#        'Appropriate Monitoring of Patients Taking Long-term Medications - DMC05',
#        'Osteoporosis Testing - DMC06',
#        'Testing to Confirm Chronic Obstructive Pulmonary Disease - DMC07',
#        'Doctors who Communicate Well - DMC08',
#        'Call Center – Beneficiary Hold Time - DMC09',
#        'Pneumonia Vaccine - DMC10',
#        'Access to Primary Care Doctor Visits - DMC11',
#        'Calls Disconnected When Customer Calls Health Plan - DMC12',
#        'Pharmacotherapy Management of COPD Exacerbation – Systemic Corticosteroid - DMC13',
#        'Pharmacotherapy Management of COPD Exacerbation – Bronchodilator - DMC14',
# ...

# %%
data16_2.columns
# Out:
# Index(['Contract Number',
#        'Follow-up Visit after Hospital Stay for Mental Illness (within 30 days of discharge) - DMC01',
#        'Call Answer Timeliness - DMC02',
#        'Antidepressant Medication Management (6 months) - DMC03',
#        'Continuous Beta Blocker Treatment - DMC04',
#        'Appropriate Monitoring of Patients Taking Long-term Medications - DMC05',
#        'Osteoporosis Testing - DMC06',
#        'Testing to Confirm Chronic Obstructive Pulmonary Disease - DMC07',
#        'Doctors who Communicate Well - DMC08',
#        'Call Center – Beneficiary Hold Time - DMC09',
#        'Pneumonia Vaccine - DMC10',
#        'Access to Primary Care Doctor Visits - DMC11',
#        'Calls Disconnected When Customer Calls Health Plan - DMC12',
#        'Pharmacotherapy Management of COPD Exacerbation – Systemic Corticosteroid - DMC13',
#        'Pharmacotherapy Management of COPD Exacerbation – Bronchodilator - DMC14',
# ...

# %%
data15_2.columns = ['id',
       'Follow-up Visit after Hospital Stay for Mental Illness',
       'Call Answer Timeliness',
       'Antidepressant Medication Management',
       'Continuous Beta Blocker Treatment',
       'Appropriate Monitoring of Patients',
       'Osteoporosis Testing',
       'Testing Chronic Obstructive Pulmonary Disease',
       'Doctors who Communicate Well', 'Pneumonia Vaccine',
       'Access to Primary Care Doctor Visits',
       'Special Needs Plan',
       'Systemic Corticosteroid',
       'Bronchodilator',
       'Initiation of Alcohol or other Drug Treatment',
       'Engagement of Alcohol or other Drug Treatment',
       'Reminders for Appointments',
       'Reminders for Immunizations',
       'Reminders for Screening Tests',
       'Computer used during Office Visits',
       'Computer use by Provider Helpful',
       'Computer use Made Talking to Provider Easier',
       'Breast Cancer Screening',
       'Timely Receipt of Case Files for Appeals',
       'Timely Effectuation of Appeals',
       'Drug-Drug Interactions', 'Diabetes Medication Dosing',
       'Drug Plan on Costs and Coverage',
       'Stability',
       'Medication Therapy Completion Rate',
       'Rate of Chronic Use of Atypical Antipsychotics',
       'Getting Information from Drug Plan',
       'Plan Submitted Higher Prices for Display',
       'failure rate for drugs within clinical concern',
       'failure rate for all other drugs',
       'Reminders to fill prescriptions',
       'Reminders to take medications',
       'Enrollment Timeliness', 'Grievance Rate',
       'Problems Getting Needed Care, Coverage, and Cost Information',
       'Problems with Coverage of Doctors and Hospitals',
       'Financial Reasons for Disenrollment',
       'Problems with Prescription Drug Benefits and Coverage',
       'Problems Getting Information about Prescription Drugs',
       'Beneficiary Access and Performance Problems']
data16_2.columns = ['id',
       'Follow-up Visit after Hospital Stay for Mental Illness',
       'Call Answer Timeliness',
       'Antidepressant Medication Management',
       'Continuous Beta Blocker Treatment',
       'Appropriate Monitoring of Patients Taking Long-term Medications',
       'Osteoporosis Testing',
       'Testing to Confirm Chronic Obstructive Pulmonary Disease',
       'Doctors who Communicate Well',
       'Call Center – Beneficiary Hold Time',
       'Pneumonia Vaccine',
       'Access to Primary Care Doctor Visits',
       'Calls Disconnected When Customer Calls Health Plan',
       'Pharmacotherapy Management of COPD Exacerbation – Systemic Corticosteroid - DMC13',
       'Pharmacotherapy Management of COPD Exacerbation – Bronchodilator - DMC14',
       'Initiation of Alcohol or other Drug Treatment - DMC15',
       'Engagement of Alcohol or other Drug Treatment - DMC16',
       'Reminders for Appointments - DMC17',
       'Reminders for Immunizations - DMC18',
       'Reminders for Screening Tests - DMC19',
       'Computer Used during Office Visits - DMC20',
       'Computer Use by Doctor Helpful - DMC21',
       'Computer Use Made Talking with Doctor Easier - DMC22',
       'Improving Bladder Control - DMC23',
       'Timely Receipt of Case Files for Appeals - DMD01',
       'Timely Effectuation of Appeals - DMD02',
       'Calls Disconnected When Customer Calls Drug Plan - DMD03',
       'Call Center – Beneficiary Hold Time - DMD04',
       'Drug-Drug Interactions - DMD05', 'Diabetes Medication Dosing - DMD06',
       'Drug Plan Provides Current Information on Costs and Coverage for Medicare’s Website - DMD07',
       'MPF – Stability - DMD08',
       'Rate of Chronic Use of Atypical Antipsychotics by Elderly Beneficiaries in Nursing Homes - DMD09',
       'Getting Information from Drug Plan - DMD10',
       'Call Center – Pharmacy Hold Time - DMD11',
       'Plan Submitted Higher Prices for Display on MPF - DMD12',
       'Transition monitoring - failure rate for drugs within classes of clinical concern - DMD13',
       'Transition monitoring - failure rate for all other drugs - DMD14',
       'Reminders to Fill prescriptions - DMD15',
       'Reminders to Take Medications - DMD16',
       'Enrollment Timeliness - DME01', 'Grievance Rate - DME02',
       'Disenrollment Reasons - Problems Getting Needed Care, Coverage, and Cost Information (MA-PD, MA-only) - DME03',
       'Disenrollment Reasons - Problems with Coverage of Doctors and Hospitals (MA-PD, MA-only) - DME04',
       'Disenrollment Reasons - Financial Reasons for Disenrollment (MA-PD, MA-only, PDP) - DME05',
       'Disenrollment Reasons - Problems with Prescription Drug Benefits and Coverage (MA-PD, PDP) - DME06',
       'Disenrollment Reasons - Problems Getting Information about Prescription Drugs (MA-PD, PDP) - DME07']
# Out:
# Index(['Contract Number',
#        'Follow-up Visit after Hospital Stay for Mental Illness (within 30 days of discharge) - DMC01',
#        'Call Answer Timeliness - DMC02',
#        'Antidepressant Medication Management (6 months) - DMC03',
#        'Continuous Beta Blocker Treatment - DMC04',
#        'Appropriate Monitoring of Patients Taking Long-term Medications - DMC05',
#        'Osteoporosis Testing - DMC06',
#        'Testing to Confirm Chronic Obstructive Pulmonary Disease - DMC07',
#        'Doctors who Communicate Well - DMC08', 'Pneumonia Vaccine - DMC09',
#        'Access to Primary Care Doctor Visits - DMC10',
#        'Special Needs Plan (SNP) Care Management - DMC11',
#        'Pharmacotherapy Management of COPD Exacerbation – Systemic Corticosteroid - DMC12',
#        'Pharmacotherapy Management of COPD Exacerbation – Bronchodilator - DMC13',
#        'Initiation of Alcohol or other Drug Treatment - DMC14',
# ...

# %%
data15 = data15.drop(["organization", "contract", "marketing", "parent"], axis = 1)
data16 = data16.drop(["organization", "contract", "marketing", "parent"], axis = 1)
data17 = data17.drop(["organization", "contract", "marketing", "parent"], axis = 1)
data18 = data18.drop(["organization", "contract", "marketing", "parent"], axis = 1)
data19 = data19.drop(["organization", "contract", "parent"], axis = 1)

data15 = data15.drop([0, 1, 2], axis = 0)
data16 = data16.drop([0, 1, 2], axis = 0)
data17 = data17.drop([0, 1, 2], axis = 0)
data18 = data18.drop([0, 1, 2], axis = 0)
data19 = data19.drop([0], axis = 0)

# %%
data18_2.head()
# Out:
#    Contract Number                        Organization Marketing Name  \
# 0  Contract Number                        Organization Marketing Name
# 1              NaN                                                NaN
# 2            E0654  TEAMStar Medicare Part D Prescription Drug Pro...
# 3            E2630             C and O Employees Hospital Association
# 4            E3014  Pennsylvania Public School Employees Retiremen...
#
#                              Contract Name  \
# 0                            Contract Name
# 1                                      NaN
# 2    Ibt Voluntary Employee Benefits Trust
# 3  C And O Employees' Hospital Association
# 4                        Psers Hop Program
#
#                                 Parent Organization  \
# 0                               Parent Organization
# 1                                               NaN
# 2             IBT Voluntary Employee Benefits Trust
# 3             C & O Employees' Hospital Association
# ...

# %%
data15_2 = data15_2.drop(["Organizatoin Name", "Contract Name", "Parent Organization"], axis = 1)
data16_2 = data16_2.drop(["Organizatoin Name", "Contract Name", "Parent Organization"], axis = 1)
data17_2 = data17_2.drop(["Organizatoin Name", "Contract Name", "Parent Organization"], axis = 1)
data18_2 = data18_2.drop(["Organization Marketing Name", "Contract Name", "Parent Organization"], axis = 1)
data19_2 = data19_2.drop(["Organization Marketing Name", "Contract Name", "Parent Organization"], axis = 1)

data15_2 = data15_2.drop([0, 1], axis = 0)
data16_2 = data16_2.drop([0, 1], axis = 0)
data17_2 = data17_2.drop([0, 1], axis = 0)
data18_2 = data18_2.drop([0, 1], axis = 0)
data19_2 = data19_2.drop([0, 1], axis = 0)

# %%
def clean(data):
    #Figuring out what are unique text entries to signify no data
    text = []
    for i in data.columns[1:]: 
        for j in data[data[i].str.contains("[A-Za-z]")][i].unique():
            if j not in text:
                text.append(j)

    #Dropping columns that have no data 
    data.index = np.arange(data.shape[0])
    for i in data.columns:
        if np.sum(np.array([data[i][j] in text for j in range(data.shape[0])])) == data.shape[0]:
            data = data.drop(i, axis = 1)
    
    #Dropping rows that have no data
    rows = []
    for i in range(data.shape[0]):
        if np.sum(np.array([data.iloc[i, j] not in text for j in range(1, data.shape[1])])) == 0:
            rows.append(i)
    data = data.drop(rows, axis = 0)
    
    #Getting rid of % sign 
    data = data.apply(lambda x: x.str.split("%").apply(lambda y: y[0]), axis = 0)
    
    #Converting no data to -1 
    ids = data["id"]
    data = data.drop("id", axis = 1)
    data = data.apply(lambda x: x.apply(lambda y: -1 if y in text else float(y)), axis = 0)
    data["id"] = ids
    return data

data15 = clean(data15)
data16 = clean(data16)
data17 = clean(data17)
data18 = clean(data18)
data19 = clean(data19)
data15_2 = clean(data15_2)
data16_2 = clean(data16_2)
data17_2 = clean(data17_2)
data18_2 = clean(data18_2)
data19_2 = clean(data19_2)

# %%
data15.to_csv("2015_cleaned_c_d")
data16.to_csv("2016_cleaned_c_d")
data17.to_csv("2017_cleaned_c_d")
data18.to_csv("2018_cleaned_c_d")

# %%
data19.to_csv("2019_cleaned_c")
